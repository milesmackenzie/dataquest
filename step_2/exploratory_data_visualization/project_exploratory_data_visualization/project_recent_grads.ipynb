# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
recent_grads = pd.read_csv('recent-grads.csv')
print (recent_grads.iloc[170:172])
# print (recent_grads.head(0))
# print (recent_grads.tail())
int_type = list(recent_grads.columns)      
for item in int_type:
    describe_numerical = recent_grads[item].describe()

raw_data_count = recent_grads.count()    
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.count()
# Out:
#      Rank  Major_code                  Major   Total    Men   Women  \
# 170   171        5202    CLINICAL PSYCHOLOGY  2838.0  568.0  2270.0
# 171   172        5203  COUNSELING PSYCHOLOGY  4626.0  931.0  3695.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 170      ...              648                  1293         368
# 171      ...              965                  2738         214
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 170           0.149048   25000  25000  40000           986               870
# 171           0.053621   23400  19200  26000          2403              1245
#
#      Low_wage_jobs
# 170            622
# 171            308
#
# [2 rows x 21 columns]

# %%
recent_grads.plot(x='Sample_size',y='Median',kind='scatter')
recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter')
recent_grads.plot(x='Full_time',y='Median',kind='scatter')
recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter')
recent_grads.plot(x='Men',y='Median',kind='scatter')
recent_grads.plot(x='Women',y='Median',kind='scatter')

# %%
recent_grads['Sample_size'].hist(bins=15, range=(0,5000))

# %%
recent_grads['Median'].hist(bins=15, range=(0,120000))

# %%
recent_grads['Employed'].hist(bins=20, range=(0,350000))

# %%
recent_grads['Full_time'].hist(bins=15, range=(0,250000))

# %%
recent_grads['ShareWomen'].hist(bins=10, range=(0,1.2))

# %%
recent_grads['Unemployment_rate'].hist(bins=15, range=(0,0.20))

# %%
recent_grads['Men'].hist(bins=15, range=(0,200000))

# %%
recent_grads['Women'].hist(bins=15, range=(0,210000))

# %%
# Dataquest solution for reference:
# cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

# fig = plt.figure(figsize=(5,12))
# for r in range(1,5):
#     ax = fig.add_subplot(4,1,r)
#     ax = recent_grads[cols[r]].plot(kind='hist', rot=40)

# %%
from pandas import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f45c25e92e8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45c24ee240>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f45c2a4e898>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45c27fbe48>]], dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='Women')

# %%
recent_grads = recent_grads.sort_values('Median')

recent_grads[162:].plot.bar(x='Major', y='ShareWomen')
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

recent_grads[162:].plot.bar(x='Major', y='Unemployment_rate')
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

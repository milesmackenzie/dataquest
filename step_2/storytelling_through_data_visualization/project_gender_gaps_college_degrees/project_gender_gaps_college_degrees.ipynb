# %% [markdown]
# # Plots from color_layout_annotations course

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering', 'Computer Science']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# # Comparing all majors

# %%
fig = plt.figure(figsize=(18, 3))

# Generating plots for other_cats list of degrees
for sp in range(0,6):
    ax = fig.add_subplot(2,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
   
    if sp == 0:
        ax.text(2006, 92, 'Men')
        ax.text(2005, 1, 'Women')
    elif sp == 5:
        ax.text(2008, 65, 'Men')
        ax.text(2006, 28, 'Women')
        
fig = plt.figure(figsize=(18, 3))

# Generating plots for stem_cats list of degrees
for sp in range(0,6):
    ax2 = fig.add_subplot(2,3,sp+1)
    ax2.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(stem_cats[sp])
    ax2.tick_params(bottom="off", top="off", left="off", right="off")
    
    
    if sp == 0:
        ax2.text(2008, 87, 'Men')
        ax2.text(2006, 8, 'Women')
    elif sp == 5:
        ax2.text(2008, 91, 'Men')
        ax2.text(2006, 1, 'Women')
        
fig = plt.figure(figsize=(18, 3))

# Generating plots for lib_arts_cats list of degrees
for sp in range(0,5):
    ax3 = fig.add_subplot(2,3,sp+1)
    ax3.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax3.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax3.spines["right"].set_visible(False)    
    ax3.spines["left"].set_visible(False)
    ax3.spines["top"].set_visible(False)    
    ax3.spines["bottom"].set_visible(False)
    ax3.set_xlim(1968, 2011)
    ax3.set_ylim(0,100)
    ax3.set_title(lib_arts_cats[sp])
    ax3.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax3.text(2008, 79, 'Men')
        ax3.text(2006, 15, 'Women')
    elif sp == 4:
        ax3.text(2008, 62, 'Men')
        ax3.text(2006, 35, 'Women')
        
plt.show()

# %% [markdown]
# # Removing x-axis labels

# %%
fig = plt.figure(figsize=(18, 3))


for sp in range(0,6):
    ax = fig.add_subplot(2,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    
    if sp == 0:
        ax.text(2006, 92, 'Men')
        ax.text(2005, 1, 'Women')
    elif sp == 5:
        ax.text(2008, 65, 'Men')
        ax.text(2006, 28, 'Women')
        
fig = plt.figure(figsize=(18, 3))
     
for sp in range(0,6):
    ax2 = fig.add_subplot(2,3,sp+1)
    ax2.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(stem_cats[sp])
    ax2.tick_params(bottom="off", top="off", left="off", right="off")
    ax2.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if sp == 0:
        ax2.text(2008, 87, 'Men')
        ax2.text(2006, 8, 'Women')
    elif sp == 5:
        ax2.text(2008, 91, 'Men')
        ax2.text(2006, 1, 'Women')
        
fig = plt.figure(figsize=(18, 3))


for sp in range(0,5):
    ax3 = fig.add_subplot(2,3,sp+1)
    ax3.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax3.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax3.spines["right"].set_visible(False)    
    ax3.spines["left"].set_visible(False)
    ax3.spines["top"].set_visible(False)    
    ax3.spines["bottom"].set_visible(False)
    ax3.set_xlim(1968, 2011)
    ax3.set_ylim(0,100)
    ax3.set_title(lib_arts_cats[sp])
    ax3.tick_params(bottom="off", top="off", left="off", right="off")
    ax3.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if sp == 0:
        ax3.text(2008, 79, 'Men')
        ax3.text(2006, 15, 'Women')
        
    elif sp == 4:
        ax3.text(2008, 62, 'Men')
        ax3.text(2006, 35, 'Women')
        
plt.show()

# %% [markdown]
# # Setting y-axis labels and only placing x-axis labels on bottom plots

# %%
fig = plt.figure(figsize=(18, 3))


for sp in range(0,6):
    ax = fig.add_subplot(2,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    
    if sp == 0:
        ax.text(2006, 92, 'Men')
        ax.text(2005, 1, 'Women')
    elif sp == 5:
        ax.text(2008, 65, 'Men')
        ax.text(2006, 28, 'Women')
        
fig = plt.figure(figsize=(18, 3))
     
for sp in range(0,6):
    ax2 = fig.add_subplot(2,3,sp+1)
    ax2.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(stem_cats[sp])
    ax2.tick_params(bottom="off", top="off", left="off", right="off")
    ax2.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax2.set_yticks([0,100])
    
    if sp == 0:
        ax2.text(2008, 87, 'Men')
        ax2.text(2006, 8, 'Women')
    elif sp == 5:
        ax2.text(2008, 91, 'Men')
        ax2.text(2006, 1, 'Women')
        
fig = plt.figure(figsize=(18, 3))


for sp in range(0,5):
    ax3 = fig.add_subplot(2,3,sp+1)
    ax3.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax3.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax3.spines["right"].set_visible(False)    
    ax3.spines["left"].set_visible(False)
    ax3.spines["top"].set_visible(False)    
    ax3.spines["bottom"].set_visible(False)
    ax3.set_xlim(1968, 2011)
    ax3.set_ylim(0,100)
    ax3.set_title(lib_arts_cats[sp])
    ax3.tick_params(bottom="off", top="off", left="off", right="off")
    ax3.set_yticks([0,100])
    
    if sp == 0:
        ax3.text(2008, 79, 'Men')
        ax3.text(2006, 15, 'Women')
        ax3.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    elif sp == 1:
        ax3.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    elif sp == 4:
        ax3.text(2008, 62, 'Men')
        ax3.text(2006, 35, 'Women')
        
plt.show()

# %% [markdown]
# # Adding horizontal line at position 50

# %%
fig = plt.figure(figsize=(18, 3))


for sp in range(0,6):
    ax = fig.add_subplot(2,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax.text(2006, 92, 'Men')
        ax.text(2005, 1, 'Women')
    elif sp == 5:
        ax.text(2008, 65, 'Men')
        ax.text(2006, 28, 'Women')
        
fig = plt.figure(figsize=(18, 3))
     
for sp in range(0,6):
    ax2 = fig.add_subplot(2,3,sp+1)
    ax2.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(stem_cats[sp])
    ax2.tick_params(bottom="off", top="off", left="off", right="off")
    ax2.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax2.set_yticks([0,100])
    ax2.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax2.text(2008, 87, 'Men')
        ax2.text(2006, 8, 'Women')
    elif sp == 5:
        ax2.text(2008, 91, 'Men')
        ax2.text(2006, 1, 'Women')
        
fig = plt.figure(figsize=(18, 3))


for sp in range(0,5):
    ax3 = fig.add_subplot(2,3,sp+1)
    ax3.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax3.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax3.spines["right"].set_visible(False)    
    ax3.spines["left"].set_visible(False)
    ax3.spines["top"].set_visible(False)    
    ax3.spines["bottom"].set_visible(False)
    ax3.set_xlim(1968, 2011)
    ax3.set_ylim(0,100)
    ax3.set_title(lib_arts_cats[sp])
    ax3.tick_params(bottom="off", top="off", left="off", right="off")
    ax3.set_yticks([0,100])
    ax3.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax3.text(2008, 79, 'Men')
        ax3.text(2006, 15, 'Women')
        ax3.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    elif sp == 1:
        ax3.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    elif sp == 4:
        ax3.text(2008, 62, 'Men')
        ax3.text(2006, 35, 'Women')
        
plt.show()

# %% [markdown]
# # Exporting file as png

# %%
fig = plt.figure(figsize=(18, 3))


for sp in range(0,6):
    ax = fig.add_subplot(2,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax.text(2006, 92, 'Men')
        ax.text(2005, 1, 'Women')
    elif sp == 5:
        ax.text(2008, 65, 'Men')
        ax.text(2006, 28, 'Women')
fig.savefig("gender_degrees.png")  
plt.show()

# %%
fig = plt.figure(figsize=(18, 3))
     
for sp in range(0,6):
    ax2 = fig.add_subplot(2,3,sp+1)
    ax2.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax2.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax2.spines["right"].set_visible(False)    
    ax2.spines["left"].set_visible(False)
    ax2.spines["top"].set_visible(False)    
    ax2.spines["bottom"].set_visible(False)
    ax2.set_xlim(1968, 2011)
    ax2.set_ylim(0,100)
    ax2.set_title(stem_cats[sp])
    ax2.tick_params(bottom="off", top="off", left="off", right="off")
    ax2.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax2.set_yticks([0,100])
    ax2.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax2.text(2008, 87, 'Men')
        ax2.text(2006, 8, 'Women')
    elif sp == 5:
        ax2.text(2008, 91, 'Men')
        ax2.text(2006, 1, 'Women')
fig.savefig("gender_degrees2.png") 
plt.show()

# %%
fig = plt.figure(figsize=(18, 3))

for sp in range(0,5):
    ax3 = fig.add_subplot(2,3,sp+1)
    ax3.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax3.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax3.spines["right"].set_visible(False)    
    ax3.spines["left"].set_visible(False)
    ax3.spines["top"].set_visible(False)    
    ax3.spines["bottom"].set_visible(False)
    ax3.set_xlim(1968, 2011)
    ax3.set_ylim(0,100)
    ax3.set_title(lib_arts_cats[sp])
    ax3.tick_params(bottom="off", top="off", left="off", right="off")
    ax3.set_yticks([0,100])
    ax3.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax3.text(2008, 79, 'Men')
        ax3.text(2006, 15, 'Women')
        ax3.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    elif sp == 1:
        ax3.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    elif sp == 4:
        ax3.text(2008, 62, 'Men')
        ax3.text(2006, 35, 'Women')
        
fig.savefig("gender_degrees3.png")        
plt.show()
